# %%
import pickle

# %%
Final_Model=pickle.load(open("Insurance_predictor_final.sav",'rb'))
age=int(input("Enter the age:"))
bmi=float(input("Enter the bmi:"))
Child=int(input("How many Children:"))
Gender=int(input("Enter 1 if male else 0:"))
smoker=input("Enter 1 if smoker:")
# Out:
# Enter the age: 18
# Enter the bmi: 33.7
# How many Children: 1
# Enter 1 if male else 0: 1
# Enter 1 if smoker: 0

# %%
result=Final_Model.predict([[age,bmi,Child,Gender,smoker]])
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([3467.38159142])
